# %% [markdown]
# # Libraries 📚

# %%
from pyspark.sql import functions as F
from pyspark.sql import DataFrame
from pyspark.sql.functions import col, when, count
import pyspark.sql.types as DataTypes

# %%
data_path = "s3://full-stack-bigdata-datasets/Big_Data/Project_Steam/steam_game_output.json"
steam_df = spark.read.json(data_path)

# %% [markdown]
# # Our data 🧐

# %%
steam_df.limit(10).toPandas()
# Out:
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:122: UserWarning: toPandas attempted Arrow optimization because 'spark.sql.execution.arrow.pyspark.enabled' is set to true; however, failed by the reason below:
#   Unable to convert the field data. If this column is not necessary, you may consider dropping it or converting to primitive type before the conversion.
# Direct cause: Nested StructType not supported in conversion to Arrow
# Attempting non-optimization as 'spark.sql.execution.arrow.pyspark.fallback.enabled' is set to true.
#   warn(msg)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>data</th>
#       <th>id</th>
#     </tr>
#   </thead>
# ...

# %%
display(steam_df.limit(10))
steam_df.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
steam_df.select([count(when(col(c).isNull(), c)).alias(c) for c in steam_df.columns]).show()
# Out:
# +----+---+
# |data| id|
# +----+---+
# |   0|  0|
# +----+---+

# %%
steam_ext = steam_df.select('data.*')
display(steam_ext.limit(9))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
steam_ext.printSchema()
# Out:
# root
#  |-- appid: long (nullable = true)
#  |-- categories: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ccu: long (nullable = true)
#  |-- developer: string (nullable = true)
#  |-- discount: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- header_image: string (nullable = true)
#  |-- initialprice: string (nullable = true)
#  |-- languages: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- negative: long (nullable = true)
#  |-- owners: string (nullable = true)
#  |-- platforms: struct (nullable = true)
#  |    |-- linux: boolean (nullable = true)
#  |    |-- mac: boolean (nullable = true)
#  |    |-- windows: boolean (nullable = true)
#  |-- positive: long (nullable = true)
#  |-- price: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- required_age: string (nullable = true)
#  |-- short_description: string (nullable = true)
# ...

# %%
(steam_ext.selectExpr("publisher as publisher", "name as name")).groupBy('publisher').count().sort('count', ascending=False).show(5)
# Out:
# +--------------+-----+
# |     publisher|count|
# +--------------+-----+
# |Big Fish Games|  422|
# |        8floor|  202|
# |          SEGA|  165|
# |Strategy First|  151|
# |   Square Enix|  141|
# +--------------+-----+
# only showing top 5 rows

# %%
# transform
steam_clean = steam_ext \
    .withColumn('linux', F.col('platforms.linux')) \
    .withColumn('mac', F.col('platforms.mac')) \
    .withColumn('windows', F.col('platforms.windows')) \
    .withColumn('rating', F.col('positive') / (F.col('positive') + F.col('negative'))) \
    .withColumn('release_date', F.to_date(F.unix_timestamp(F.col('release_date'), 'yyyy/M/d').cast("timestamp"))) \
    .withColumn('price', F.col('price').cast(DataTypes.FloatType())) \
    .withColumn('initial_price', F.col('initialprice').cast(DataTypes.FloatType())) \
    .withColumn('discount', F.col('discount').cast(DataTypes.FloatType())) \

# %%
steam_clean = steam_clean \
    .drop('platforms') \
    .drop('tags') \
    .drop('categories') \
    .drop('website') \
    .drop('header_image')

# %%
display(steam_clean.limit(9))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
steam_clean = (steam_clean
    .withColumn('owners', F.split(F.col('owners'), ' ')) 
    .withColumn('owners', 
        F.expr("cast(regexp_replace(owners[0], ',', '') as int) + cast(regexp_replace(owners[2], ',', '') as int)") / 2)
    .withColumn('revenue', F.col('owners') * F.col('price'))
)

# %%
def explode_column(steam_clean, column_name):
    return steam_clean.withColumn(column_name, F.explode(F.split(F.col(column_name), ',')))

steam_clean = explode_column(steam_clean, 'genre')
steam_clean = explode_column(steam_clean, 'languages')

# %%
display(steam_clean.limit(9))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
steam_clean.count()
# Out:
# Out[15]: 579641

# %% [markdown]
# ### Analysis at the "macro" level 👀

# %% [markdown]
# ##### Which publisher has released the most games on Steam?

# %%
steam_clean.select('appid').distinct().count()
# Out:
# Out[16]: 55691

# %%
unique_game_counts = (
    steam_clean.select('publisher', 'appid')
        .distinct()
        .groupBy('publisher')
        .count()
        .orderBy('count', ascending=False)
        .limit(5)
)
display(unique_game_counts)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>publisher</th><th>count</th></tr></thead><tbody><tr><td>Big Fish Games</td><td>422</td></tr><tr><td>8floor</td><td>202</td></tr><tr><td>SEGA</td><td>165</td></tr><tr><td>Strategy First</td><td>151</td></tr><tr><td>Square Enix</td><td>141</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
display(unique_game_counts)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>publisher</th><th>count</th></tr></thead><tbody><tr><td>Big Fish Games</td><td>422</td></tr><tr><td>8floor</td><td>202</td></tr><tr><td>SEGA</td><td>165</td></tr><tr><td>Strategy First</td><td>151</td></tr><tr><td>Square Enix</td><td>141</td></tr></tbody></table></div>

# %%
steam_clean.filter(steam_clean['appid'].isNull()).show()
# Out:
# +-----+---+---------+--------+-----+------------+---------+----+--------+------+--------+-----+---------+------------+------------+-----------------+----+-----+---+-------+------+-------------+-------+
# |appid|ccu|developer|discount|genre|initialprice|languages|name|negative|owners|positive|price|publisher|release_date|required_age|short_description|type|linux|mac|windows|rating|initial_price|revenue|
# +-----+---+---------+--------+-----+------------+---------+----+--------+------+--------+-----+---------+------------+------------+-----------------+----+-----+---+-------+------+-------------+-------+
# +-----+---+---------+--------+-----+------------+---------+----+--------+------+--------+-----+---------+------------+------------+-----------------+----+-----+---+-------+------+-------------+-------+

# %%
publisher_counts = (
    steam_clean.groupBy('publisher') 
        .agg(F.count('appid').alias('game_count')) 
)
most_games_publisher = (
    publisher_counts.orderBy(F.col('game_count').desc()) 
    .limit(5) 
)
most_games_publisher.show()
# Out:
# +--------------------+----------+
# |           publisher|game_count|
# +--------------------+----------+
# |                Hede|      8121|
# |              Dnovel|      2543|
# |       Blender Games|      2274|
# |             Ubisoft|      2135|
# |Daedalic Entertai...|      1920|
# +--------------------+----------+

# %%
display(most_games_publisher)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>publisher</th><th>game_count</th></tr></thead><tbody><tr><td>Hede</td><td>8121</td></tr><tr><td>Dnovel</td><td>2543</td></tr><tr><td>Blender Games</td><td>2274</td></tr><tr><td>Ubisoft</td><td>2135</td></tr><tr><td>Daedalic Entertainment</td><td>1920</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Big Fish Games released the most on steam

# %% [markdown]
# #### What are the best rated games?

# %%
best_rated_games = (
    steam_clean.select('name', 'publisher', 'rating', 'release_date') 
        .orderBy(F.col('rating').desc()) 
        .limit(10) 
)

best_rated_games.show()
# Out:
# +--------------------+-----------------+------+------------+
# |                name|        publisher|rating|release_date|
# +--------------------+-----------------+------+------------+
# |Fist Of Heaven & ...|Victor Martinelli|   1.0|  2019-06-28|
# |      Rotund Rebound|            Dahku|   1.0|  2022-04-01|
# |Fist Of Heaven & ...|Victor Martinelli|   1.0|  2019-06-28|
# |Fist Of Heaven & ...|Victor Martinelli|   1.0|  2019-06-28|
# |Fist Of Heaven & ...|Victor Martinelli|   1.0|  2019-06-28|
# |       Cube Defender| Simon Codrington|   1.0|  2019-01-06|
# |      Rotund Rebound|            Dahku|   1.0|  2022-04-01|
# |Fist Of Heaven & ...|Victor Martinelli|   1.0|  2019-06-28|
# |      Rotund Rebound|            Dahku|   1.0|  2022-04-01|
# |      Rotund Rebound|            Dahku|   1.0|  2022-04-01|
# +--------------------+-----------------+------+------------+

# %% [markdown]
# This doesn't help us very much
# let's take a look at positive Vs  negative

# %%
most_pos_reviews = (
    steam_clean.select('name', 'publisher', 'positive')
        .orderBy(F.col('positive').desc())
        .limit(10) 
)
most_pos_reviews.show()
# Out:
# +--------------------+---------+--------+
# |                name|publisher|positive|
# +--------------------+---------+--------+
# |Counter-Strike: G...|    Valve| 5943345|
# |Counter-Strike: G...|    Valve| 5943345|
# |Counter-Strike: G...|    Valve| 5943345|
# |Counter-Strike: G...|    Valve| 5943345|
# |Counter-Strike: G...|    Valve| 5943345|
# |Counter-Strike: G...|    Valve| 5943345|
# |Counter-Strike: G...|    Valve| 5943345|
# |Counter-Strike: G...|    Valve| 5943345|
# |Counter-Strike: G...|    Valve| 5943345|
# |Counter-Strike: G...|    Valve| 5943345|
# +--------------------+---------+--------+

# %%
display(
    steam_clean.groupBy('name').max('positive', 'rating').orderBy('max(positive)', ascending=False).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>max(positive)</th><th>max(rating)</th></tr></thead><tbody><tr><td>Counter-Strike: Global Offensive</td><td>5943345</td><td>0.8830547135268165</td></tr><tr><td>Dota 2</td><td>1534895</td><td>0.828414231133127</td></tr><tr><td>Grand Theft Auto V</td><td>1229265</td><td>0.852091714934523</td></tr><tr><td>PUBG: BATTLEGROUNDS</td><td>1185361</td><td>0.5661084992616564</td></tr><tr><td>Terraria</td><td>1014711</td><td>0.978420408623737</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# This makes more sense!!
# 1. Counter-Strike
# 2. Dota 2
# 3. GTA V

# %% [markdown]
# #### Are there years with more releases? Were there more or fewer game releases during the Covid, for example?

# %%
data_with_year = steam_clean.withColumn('release_year', F.year('release_date'))

# appid by year
appid_per_year = data_with_year.groupBy('release_year').count()
appid_per_year.orderBy('release_year').show()

# COVID-19 (2020-2022)
covid_period = data_with_year.filter((F.col('release_year') >= 2020) & (F.col('release_year') <= 2022))
appid_covid = covid_period.groupBy('release_year').count().orderBy('release_year')

appid_covid.show()
# Out:
# +------------+-----+
# |release_year|count|
# +------------+-----+
# |        null| 2354|
# |        1997|    7|
# |        1998|    8|
# |        1999|   15|
# |        2000|   17|
# |        2001|   31|
# |        2002|   16|
# |        2003|   26|
# |        2004|   51|
# |        2005|   30|
# |        2006|  315|
# |        2007|  468|
# |        2008|  843|
# |        2009| 1696|
# |        2010| 1591|
# |        2011| 2152|
# |        2012| 3073|
# |        2013| 5807|
# |        2014|14203|
# |        2015|23607|
# +------------+-----+
# only showing top 20 rows
#
# +------------+------+
# |release_year| count|
# +------------+------+
# |        2020| 94501|
# |        2021|100655|
# |        2022| 88114|
# +------------+------+

# %% [markdown]
# #### How are the prizes distributed? Are there many games with a discount?

# %%
discounted_games = steam_clean.filter(F.col('price') < F.col('initial_price'))

total_games = steam_clean.count()

num_discounted_games = discounted_games.count()

percentage_discounted = (num_discounted_games / total_games) * 100 if total_games > 0 else 0

print(f"Total number of games: {total_games}")
print(f"Number of games with a discount: {num_discounted_games}")
print(f"Percentage of games with a discount: {percentage_discounted:.2f}%")
# Out:
# Total number of games: 579641
# Number of games with a discount: 37531
# Percentage of games with a discount: 6.47%

# %%
df = steam_clean.selectExpr(
    "appid as appid", 
    "price", 
    "(initial_price - price) as discount" 
).orderBy(F.desc("discount")) 

display(df.limit(9))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appid</th><th>price</th><th>discount</th></tr></thead><tbody><tr><td>868400</td><td>3366.0</td><td>6534.0</td></tr><tr><td>868400</td><td>3366.0</td><td>6534.0</td></tr><tr><td>502500</td><td>1499.0</td><td>6000.0</td></tr><tr><td>502500</td><td>1499.0</td><td>6000.0</td></tr><tr><td>502500</td><td>1499.0</td><td>6000.0</td></tr><tr><td>502500</td><td>1499.0</td><td>6000.0</td></tr><tr><td>502500</td><td>1499.0</td><td>6000.0</td></tr><tr><td>502500</td><td>1499.0</td><td>6000.0</td></tr><tr><td>502500</td><td>1499.0</td><td>6000.0</td></tr></tbody></table></div>

# %% [markdown]
# #### What are the most represented languages?

# %%
display(
    steam_clean.groupBy('languages').count().orderBy('count', ascending=False).limit(10),
    steam_clean.groupBy('languages').count().orderBy('count', ascending=True).limit(5)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>languages</th><th>count</th></tr></thead><tbody><tr><td>English</td><td>154137</td></tr><tr><td> German</td><td>38220</td></tr><tr><td> Simplified Chinese</td><td>36910</td></tr><tr><td> Russian</td><td>36872</td></tr><tr><td> French</td><td>36590</td></tr><tr><td> Spanish - Spain</td><td>33859</td></tr><tr><td> Japanese</td><td>28191</td></tr><tr><td> Italian</td><td>25104</td></tr><tr><td> Portuguese - Brazil</td><td>19650</td></tr><tr><td> Korean</td><td>19022</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
language_counts = steam_clean.groupBy('languages').count()
top_languages = language_counts.orderBy('count', ascending=False).limit(10)
#least_languages = language_counts.orderBy('count', ascending=True).limit(5)

display(top_languages)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>languages</th><th>count</th></tr></thead><tbody><tr><td>English</td><td>154137</td></tr><tr><td> German</td><td>38220</td></tr><tr><td> Simplified Chinese</td><td>36910</td></tr><tr><td> Russian</td><td>36872</td></tr><tr><td> French</td><td>36590</td></tr><tr><td> Spanish - Spain</td><td>33859</td></tr><tr><td> Japanese</td><td>28191</td></tr><tr><td> Italian</td><td>25104</td></tr><tr><td> Portuguese - Brazil</td><td>19650</td></tr><tr><td> Korean</td><td>19022</td></tr></tbody></table></div>

# %% [markdown]
# Are there many games prohibited for children under 16/18?

# %%
total_unique_games = steam_clean.select("appid").distinct().count()

prohibited_under_16 = steam_clean.filter(F.col('required_age')> 16 ).select("appid").distinct().count()
prohibited_under_18 = steam_clean.filter(F.col('required_age') > 18 ).select("appid").distinct().count()

percentage_under_16 = (prohibited_under_16 / total_unique_games * 100) if total_unique_games > 0 else 0
percentage_under_18 = (prohibited_under_18 / total_unique_games * 100) if total_unique_games > 0 else 0

print(f"Percentage of unique games prohibited for children under 16: {percentage_under_16:.2f}%")
print(f"Percentage of unique games prohibited for children under 18: {percentage_under_18:.2f}%")
# Out:
# Percentage of unique games prohibited for children under 16: 0.48%
# Percentage of unique games prohibited for children under 18: 0.01%

# %% [markdown]
# ### Genres analysis 🕹🎮

# %%
genre_counts = steam_clean.groupBy('genre').count()
most_represented_genres = genre_counts.orderBy(F.desc('count'))

display(most_represented_genres.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre</th><th>count</th></tr></thead><tbody><tr><td> Indie</td><td>124887</td></tr><tr><td>Action</td><td>87070</td></tr><tr><td> Casual</td><td>47249</td></tr><tr><td> Adventure</td><td>41376</td></tr><tr><td>Casual</td><td>39712</td></tr><tr><td>Adventure</td><td>39032</td></tr><tr><td> Strategy</td><td>39010</td></tr><tr><td> Simulation</td><td>37902</td></tr><tr><td> RPG</td><td>28607</td></tr><tr><td> Early Access</td><td>16480</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
display(most_represented_genres.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre</th><th>count</th></tr></thead><tbody><tr><td> Indie</td><td>124887</td></tr><tr><td>Action</td><td>87070</td></tr><tr><td> Casual</td><td>47249</td></tr><tr><td> Adventure</td><td>41376</td></tr><tr><td>Casual</td><td>39712</td></tr><tr><td>Adventure</td><td>39032</td></tr><tr><td> Strategy</td><td>39010</td></tr><tr><td> Simulation</td><td>37902</td></tr><tr><td> RPG</td><td>28607</td></tr><tr><td> Early Access</td><td>16480</td></tr></tbody></table></div>

# %% [markdown]
# #### Are there any genres that have a better positive/negative review ratio?

# %%
genre_stats = steam_clean.groupBy('genre').agg(
    F.mean('rating').alias('average_rating'),
    F.count('rating').alias('games_in_genre')
)
top_genres = genre_stats.orderBy(F.desc('average_rating')).limit(10)
least_genres = genre_stats.orderBy('average_rating').limit(10)

display(top_genres, least_genres)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(
    steam_clean.groupBy('genre').agg(F.mean('rating').alias('average_rating'), F.count('rating').alias('games_in_genre')).orderBy('average_rating', ascending=False).limit(10),
    steam_clean.groupBy('genre').agg(F.mean('rating').alias('average_rating'), F.count('rating').alias('games_in_genre')).orderBy('average_rating', ascending=True).limit(10)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #### What are the most lucrative genres? 💰💸

# %%
genre_revenue_stats = steam_clean.groupBy('genre').agg(
    F.mean('revenue').alias('average_revenue')
)
top_revenue_genres = genre_revenue_stats.orderBy(F.desc('average_revenue')).limit(10)
#least_revenue_genres = genre_revenue_stats.orderBy('average_revenue').limit(10)

display(top_revenue_genres)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(steam_clean.groupBy('genre').mean('revenue').orderBy('avg(revenue)', ascending=False).limit(10),
        steam_clean.groupBy('genre').mean('revenue').orderBy('avg(revenue)', ascending=True).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Platform analysis 💿🎮📺

# %% [markdown]
# #### Are most games available on Windows/Mac/Linux instead?

# %%
total_games = steam_clean.count()
platforms = ['windows', 'linux', 'mac']

for platform in platforms:
    count_platform = steam_clean.filter(F.col(platform) == True).count()
    percentage = (count_platform / total_games * 100) if total_games > 0 else 0
    print(f"{platform}: {percentage:.2f} %")
# Out:
# windows: 99.98 %
# linux: 19.61 %
# mac: 29.26 %
